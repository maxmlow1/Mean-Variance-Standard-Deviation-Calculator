# %%
input_list = [12, 14, 5, 2, 9, 27, 8, 15, 6]

# %%
import numpy as np
new_array = np.array([
            [input_list[0], input_list[1], input_list[2]],
            [input_list[3], input_list[4], input_list[5]],
            [input_list[6], input_list[7], input_list[8]]
])

# %%
new_array
# Out:
# array([[12, 14,  5],
#        [ 2,  9, 27],
#        [ 8, 15,  6]])

# %%
new_array.shape
# Out:
# (3, 3)

# %%
mean_values = [(new_array.mean(axis=0)).tolist(), (new_array.mean(axis=1)).tolist(), float(new_array.mean())]

# %%
mean_values
# Out:
# [[7.333333333333333, 12.666666666666666, 12.666666666666666],
#  [10.333333333333334, 12.666666666666666, 9.666666666666666],
#  10.88888888888889]

# %%
dictionary = {
    "mean": mean_values
}

# %%
dictionary
# Out:
# {'mean': [[7.333333333333333, 12.666666666666666, 12.666666666666666],
#   [10.333333333333334, 12.666666666666666, 9.666666666666666],
#   10.88888888888889]}
